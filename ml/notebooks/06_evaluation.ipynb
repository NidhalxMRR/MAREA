# %% [markdown]
# # 06 Evaluation
#
# ## Purpose
#
# Final comprehensive comparison of all candidate models:
#
# - **Model Comparison**: Baselines vs. Feature Model vs. LSTM
#   - Evaluate all models on the same chronological test period
#   - Fair comparison using identical data splits
#
# - **Metrics Summary**:
#   - MAE, RMSE, R² for each model and horizon
#   - Threshold-event recall (if applicable)
#   - False-alert rate
#   - Warning lead time
#
# - **Visualization**:
#   - Error distribution across models
#   - Prediction vs. actual time series
#   - Scatter plots (predicted vs. actual)
#   - Performance by forecast horizon
#
# - **Decision**:
#   - Select best model for production
#   - Document trade-offs (accuracy vs. interpretability vs. latency)
#   - Plan deployment via `marea_ml.inference.predictor`
#
# **Output**: Final metrics and comparison plots saved to `../reports/`
